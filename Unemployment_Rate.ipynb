# %% [markdown]
# # Introduction
#
#
# **Unemployment Rate and Its Importance**:
# - Unemployment is a critical economic indicator that reflects the health of an economy. The unemployment rate is the percentage of people who are unemployed out of the total labor force. A high unemployment rate indicates economic distress, while a low rate suggests economic stability and growth.
#
# **Objective of the Analysis**:
# - This analysis aims to explore and understand the trends in the unemployment rate across various states in India. Special attention is given to the impact of Covid-19 on unemployment rates, providing insights into how different regions were affected.

# %% [markdown]
# # Data Description
#
#
# **Overview of the Dataset:**
# - The dataset contains the unemployment rate of all the states in India, observed monthly. It covers a period that includes significant economic events, such as the Covid-19 pandemic.
#
# **Key Columns in the Dataset:**
# - Region: States in India.
# - Date: The date when the unemployment rate was observed.
# - Frequency: The frequency of measurement (Monthly).
# - Estimated Unemployment Rate (%): The percentage of people unemployed in each state.
# - Estimated Employed: The percentage of people employed.
# - Estimated Labour Participation Rate (%): The percentage of people actively participating in the labor force.

# %% [markdown]
# # Data Cleaning
#
#
# **Addressing Missing Values:**
# - Missing values were identified and handled to ensure the dataset's integrity. Rows with missing values were removed to maintain the consistency and accuracy of the analysis.
#
# **Removing Outliers:**
# - Outliers can skew the analysis and lead to misleading conclusions. Using the Interquartile Range (IQR) method, outliers were detected and removed from the dataset. This ensures a more reliable analysis.

# %% [markdown]
# ## Setting Up Environment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Data Acquisition

# %%
#Loading Dataset
df1= pd.read_csv('Unemployment in India.csv')

# %% [markdown]
# ### Importing Necessary Libraries

# %%
df1
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
df2=pd.read_csv("Unemployment_Rate_upto_11_2020.csv")

# %%
df2
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %%
df1[' Date'] = pd.to_datetime(df1[' Date'])
df2[' Date'] = pd.to_datetime(df2[' Date'])

# %%
merged_data = pd.merge(df1, df2[['Region', ' Date', 'Region.1']], on=['Region', ' Date'], how='left')

# %%
merged_data
# Out:
#              Region       Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh 2019-05-31    Monthly                              3.65
# 1    Andhra Pradesh 2019-06-30    Monthly                              3.05
# 2    Andhra Pradesh 2019-07-31    Monthly                              3.75
# 3    Andhra Pradesh 2019-08-31    Monthly                              3.32
# 4    Andhra Pradesh 2019-09-30    Monthly                              5.17
# ..              ...        ...        ...                               ...
# 763             NaN        NaT        NaN                               NaN
# 764             NaN        NaT        NaN                               NaN
# 765             NaN        NaT        NaN                               NaN
# 766             NaN        NaT        NaN                               NaN
# 767             NaN        NaT        NaN                               NaN
#
# ...

# %%
merged_data['Region.1'].isnull().sum()
# Out:
# 462

# %% [markdown]
# #### Inspecting Data

# %%
df1.head()
# Out:
#            Region       Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2019-05-31    Monthly                              3.65
# 1  Andhra Pradesh 2019-06-30    Monthly                              3.05
# 2  Andhra Pradesh 2019-07-31    Monthly                              3.75
# 3  Andhra Pradesh 2019-08-31    Monthly                              3.32
# 4  Andhra Pradesh 2019-09-30    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
df1.tail()
# Out:
#     Region  Date  Frequency   Estimated Unemployment Rate (%)  \
# 763    NaN   NaT        NaN                               NaN
# 764    NaN   NaT        NaN                               NaN
# 765    NaN   NaT        NaN                               NaN
# 766    NaN   NaT        NaN                               NaN
# 767    NaN   NaT        NaN                               NaN
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Area
# 763                  NaN                                       NaN  NaN
# 764                  NaN                                       NaN  NaN
# 765                  NaN                                       NaN  NaN
# 766                  NaN                                       NaN  NaN
# 767                  NaN                                       NaN  NaN

# %%
df1.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        740.000000         7.400000e+02
# mean                          11.787946         7.204460e+06
# std                           10.721298         8.087988e+06
# min                            0.000000         4.942000e+04
# 25%                            4.657500         1.190404e+06
# 50%                            8.350000         4.744178e+06
# 75%                           15.887500         1.127549e+07
# max                           76.740000         4.577751e+07
#
#         Estimated Labour Participation Rate (%)
# count                                740.000000
# mean                                  42.630122
# std                                    8.111094
# min                                   13.330000
# 25%                                   38.062500
# 50%                                   41.160000
# 75%                                   45.505000
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    datetime64[ns]
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: datetime64[ns](1), float64(3), object(3)
# memory usage: 42.1+ KB

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# #### Checking for Missing Values

# %%
df1.isnull().sum()
# Out:
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %%
df1.dropna(inplace=True)

# %%
df1
# Out:
#              Region       Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh 2019-05-31    Monthly                              3.65
# 1    Andhra Pradesh 2019-06-30    Monthly                              3.05
# 2    Andhra Pradesh 2019-07-31    Monthly                              3.75
# 3    Andhra Pradesh 2019-08-31    Monthly                              3.32
# 4    Andhra Pradesh 2019-09-30    Monthly                              5.17
# ..              ...        ...        ...                               ...
# 749     West Bengal 2020-02-29    Monthly                              7.55
# 750     West Bengal 2020-03-31    Monthly                              6.67
# 751     West Bengal 2020-04-30    Monthly                             15.63
# 752     West Bengal 2020-05-31    Monthly                             15.22
# 753     West Bengal 2020-06-30    Monthly                              9.86
#
# ...

# %%
df1.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %% [markdown]
# #### Convert Datatypes

# %%
df1['Date'] = pd.to_datetime(df1[' Date'])

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# #### Basic Statistics

# %%
df1.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        740.000000         7.400000e+02
# mean                          11.787946         7.204460e+06
# std                           10.721298         8.087988e+06
# min                            0.000000         4.942000e+04
# 25%                            4.657500         1.190404e+06
# 50%                            8.350000         4.744178e+06
# 75%                           15.887500         1.127549e+07
# max                           76.740000         4.577751e+07
#
#         Estimated Labour Participation Rate (%)
# count                                740.000000
# mean                                  42.630122
# std                                    8.111094
# min                                   13.330000
# 25%                                   38.062500
# 50%                                   41.160000
# 75%                                   45.505000
# ...

# %% [markdown]
# #### Time Series Analysis

# %% [markdown]
# # Unemployment Rate Over Time
#
#
# #### Trends and Patterns
#
#
#
# The unemployment rate trends over time for each region were analyzed using faceted line plots.
#
#
# **Key Insight:**
#
# - There were significant spikes in the unemployment rate during the Covid-19 pandemic across most regions. This highlights the widespread economic impact of the pandemic.

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df1, x=' Date', y=' Estimated Unemployment Rate (%)', hue='Region')
plt.xlabel(' Date')
plt.ylabel('Estimated Unemployment Rate (%)')
plt.title('Unemployment Rate Over Time by Region')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# # Distribution Analysis
#
#
# ### Understanding the Spread of Unemployment Rates
#
#
# **The distribution of the unemployment rate across all states was analyzed. The histogram below shows the frequency of different unemployment rates.**
#
#
# ***Key Insight:***
#
# - The majority of states have an unemployment rate between X% and Y%, indicating that most states fall within this range.

# %% [markdown]
# #### Distribution Analysis

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df1[' Estimated Unemployment Rate (%)'], kde=True)
plt.title('Distribution of Estimated Unemployment Rate (%)')
plt.show()

# %% [markdown]
# # Regional Comparison
#
#
# ### Average Unemployment Rates Across States
#
#
# A bar plot was used to compare the average unemployment rate across different states.
#
#
# **Key Insight:**
#
# Some regions have consistently higher unemployment rates than others, indicating regional disparities that may be due to various economic and social factors.

# %% [markdown]
# #### distribution of unemployment rates across different regions.

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Region', y=' Estimated Unemployment Rate (%)', data=df1)
plt.xlabel('Region')
plt.ylabel('Unemployment Rate (%)')
plt.title('Unemployment Rate Distribution by Region')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Here are the summarized insights from the graph:
#
# 1. **High Unemployment Regions:**
#    - Haryana, Himachal Pradesh, and Delhi have the highest median unemployment rates with significant variability.
#
# 2. **Low Unemployment Regions:**
#    - Andhra Pradesh, Gujarat, Maharashtra, and Uttar Pradesh show lower median unemployment rates with more consistent distribution.
#
# 3. **Outliers:**
#    - Regions like Goa, Jammu & Kashmir, and Telangana exhibit significant outliers, indicating periods or areas with extremely high unemployment rates.
#
# 4. **Regional Patterns:**
#    - Northern and Western states generally have higher unemployment rates compared to Southern states.
#    - Eastern states like Bihar and Assam show moderate unemployment rates with considerable variability.
#
# 5. **Overall Variability:**
#    - The unemployment rates during COVID-19 varied widely across regions, highlighting the uneven economic impact of the pandemic.

# %% [markdown]
# ### Visualizations

# %% [markdown]
# #### Faceted Line Plots:

# %%
# Faceted line plot for Unemployment Rate by Region1
g = sns.FacetGrid(df1, col="Region", col_wrap=3, height=4, aspect=1.5)
g.map(sns.lineplot, " Date", " Estimated Unemployment Rate (%)")
g.set_axis_labels(" Date", "Unemployment Rate (%)")
g.set_titles("{col_name} Region")
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Unemployment Rate Over Time by Region1')
plt.show()

# %% [markdown]
# ####  Bar Plots:

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Region', y=' Estimated Unemployment Rate (%)', data=df1, ci=None)
plt.xlabel('Region')
plt.ylabel('Average Unemployment Rate (%)')
plt.title('Average Unemployment Rate by Region')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Harshita\AppData\Local\Temp\ipykernel_2664\2934807677.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Region', y=' Estimated Unemployment Rate (%)', data=df1, ci=None)

# %% [markdown]
# Here are the summarized insights:
#
# 1. **Highest Average Unemployment Rates:**
#    - **Tripura** and **Haryana** have the highest average unemployment rates, indicating these regions were most affected.
#
# 2. **Moderately High Unemployment Rates:**
#    - **Bihar, Delhi, Himachal Pradesh, Jammu & Kashmir**, and **Telangana** also exhibit relatively high average unemployment rates.
#
# 3. **Lowest Average Unemployment Rates:**
#    - **Andhra Pradesh, Gujarat, Madhya Pradesh**, and **Odisha** have the lowest average unemployment rates, suggesting these regions were less affected.
#
# 4. **Regional Trends:**
#    - **Northern states** (Haryana, Himachal Pradesh, Jammu & Kashmir) and **Eastern states** (Bihar, Tripura) generally show higher unemployment rates.
#    - **Southern states** (Andhra Pradesh, Tamil Nadu, Karnataka) and **Western states** (Gujarat, Maharashtra) tend to have lower unemployment rates.
#
# This graph highlights the uneven impact of COVID-19 on unemployment across different regions, with certain areas experiencing significantly higher average rates.

# %% [markdown]
# #### Heat Maps

# %% [markdown]
# # Heatmap Analysis
#
#
# ### Visual Representation of Unemployment Trends
#
#
# A heatmap was created to visualize the unemployment rate over time for each region. This helps identify periods of high and low unemployment rates.
#
#
# **Key Insight:**
#
# Some regions experienced more drastic changes in unemployment rates compared to others. This visual representation helps pinpoint when and where significant changes occurred.

# %%
# Pivot data for heatmap
pivot_table = df1.pivot_table(values=' Estimated Unemployment Rate (%)', index=' Date', columns='Region')

# Heatmap for Unemployment Rate by Region
plt.figure(figsize=(12, 8))
sns.heatmap(pivot_table, cmap="YlGnBu", cbar_kws={'label': 'Unemployment Rate (%)'})
plt.xlabel('Region')
plt.ylabel('Date')
plt.title('Heatmap of Unemployment Rate Over Time by Region')
plt.show()

# %% [markdown]
# ### UNIVARIATE ANALYSIS

# %%
# Histogram of the unemployment rate
df1[' Estimated Unemployment Rate (%)'].hist()
plt.title('Distribution of Estimated Unemployment Rate (%)')
plt.xlabel('Estimated Unemployment Rate (%)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Here are the summarized insights:
#
# 1. **Most Common Unemployment Rates:**
#    - The majority of the observations have unemployment rates between 0% and 10%.
#    - There is a notable frequency peak around 5%-10%, indicating that this range is the most common for unemployment rates during the period analyzed.
#
# 2. **Less Frequent High Unemployment Rates:**
#    - Unemployment rates above 10% are less common, with frequencies gradually decreasing as the rate increases.
#    - Rates above 30% are rare, indicating that extremely high unemployment rates were not typical during the period.
#
# 3. **Skewness:**
#    - The distribution is right-skewed, meaning that while lower unemployment rates are common, there are fewer instances of very high unemployment rates.
#
# 4. **Outliers:**
#    - There are a few outliers with unemployment rates as high as 70%-80%, suggesting that certain regions or periods experienced unusually high unemployment.
#
# This histogram indicates that while low unemployment rates were prevalent during COVID-19, there were significant instances of higher unemployment in some areas.

# %%
sns.histplot(data=df1,x=" Estimated Unemployment Rate (%)")
# Out:
# <Axes: xlabel=' Estimated Unemployment Rate (%)', ylabel='Count'>

# %%
sns.histplot(data=df1,x=" Estimated Employed")
# Out:
# <Axes: xlabel=' Estimated Employed', ylabel='Count'>

# %%
sns.histplot(data=df1,x=" Estimated Labour Participation Rate (%)")
# Out:
# <Axes: xlabel=' Estimated Labour Participation Rate (%)', ylabel='Count'>

# %% [markdown]
# ### BIVARIATE ANALYSIS

# %%
# Scatter plot of unemployment rate over time
df1['Date'] = pd.to_datetime(df1['Date'])  # Convert to datetime
plt.figure(figsize=(10, 6))
plt.scatter(df1['Date'], df1[' Estimated Unemployment Rate (%)'])
plt.title('Unemployment Rate Over Time')
plt.xlabel('Date')
plt.ylabel(' Estimated Unemployment Rate (%)')
plt.show()

# %% [markdown]
#
# **The unemployment rate remains relatively stable from mid-2019 to early 2020.
# There is a significant increase in the unemployment rate starting around March 2020, reaching peaks in the subsequent months.
# This increase around early 2020 likely correlates with global events such as the COVID-19 pandemic, which led to widespread economic disruptions and increased unemployment rates worldwide.**

# %%
# Correlation between unemployment rate and other numerical features
(df1[[' Estimated Unemployment Rate (%)', ' Estimated Employed', ' Estimated Labour Participation Rate (%)']].corr())
# Out:
#                                            Estimated Unemployment Rate (%)  \
#  Estimated Unemployment Rate (%)                                  1.000000
#  Estimated Employed                                              -0.222876
#  Estimated Labour Participation Rate (%)                          0.002558
#
#                                            Estimated Employed  \
#  Estimated Unemployment Rate (%)                    -0.222876
#  Estimated Employed                                  1.000000
#  Estimated Labour Participation Rate (%)             0.011300
#
#                                            Estimated Labour Participation Rate (%)
#  Estimated Unemployment Rate (%)                                          0.002558
#  Estimated Employed                                                       0.011300
#  Estimated Labour Participation Rate (%)                                  1.000000

# %%
# Scatter plot of unemployment rate vs. labor participation rate
plt.figure(figsize=(10, 6))
sns.scatterplot(x=' Estimated Labour Participation Rate (%)', y=' Estimated Unemployment Rate (%)', data=df1)
plt.title('Unemployment Rate vs. Labour Participation Rate')
plt.xlabel('Estimated Labour Participation Rate (%)')
plt.ylabel('Estimated Unemployment Rate (%)')
plt.show()

# %% [markdown]
# **From the scatter plot, the following observations can be made:**
#
# - The data points for the unemployment rate and labor force participation rate are quite dispersed, but some trends can be seen.
# - Higher labor force participation rates (above 50%) tend to correspond with lower unemployment rates.
# - Lower labor force participation rates (below 40%) correspond with a wide range of unemployment rates, from 0% to 70%.
# - This chart can be used to analyze the relationship between the unemployment rate and the labor force participation rate, helping to identify potential economic patterns and trends.

# %%
sns.scatterplot(data=df1,x=" Estimated Unemployment Rate (%)",y=" Estimated Labour Participation Rate (%)")
# Out:
# <Axes: xlabel=' Estimated Unemployment Rate (%)', ylabel=' Estimated Labour Participation Rate (%)'>

# %% [markdown]
# # Conclusion
#
#
#
# ## Summarizing Key Findings:
#
# **The analysis highlighted significant variations in unemployment rates across different regions and time periods.
# The Covid-19 pandemic had a notable impact on unemployment rates in most regions.
# There are clear disparities in unemployment rates among different states, suggesting the need for targeted economic policies.**
#
#
# ## Future Directions:
#
# **Further analysis could include other factors such as economic growth, industry distribution, and demographic changes to provide a more comprehensive understanding of unemployment trends.**
